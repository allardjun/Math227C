# %% [markdown]
# # Math 227C R Jupyter test code

# %%
x <- 227
print(cat("Hello from Math ", x, "!\n"))
# Out:
# Hello from Math  227 !
# NULL

# %%
# Generate random numbers
# set.seed(123)  # For reproducibility
x <- 1:100
y <- rnorm(100)

# Plot the random numbers
plot(x, y, 
type = "p", # points
col = "red", 
pch = 16, 
xlab = "Index", 
ylab = "Random Values", 
main = "Random Numbers Plot")

# Add a legend
legend("topright", legend = "Random Numbers", col = "red", pch = 16)
# Out:
# Plot with title “Random Numbers Plot”

# %% [markdown]
# ## Some extra queries

# %%
# In R cell
R.home()
.libPaths()
#Sys.getenv()
# Out:
# [1] "/Users/jun/miniconda3/envs/r_env/lib/R"
# [1] "/Users/jun/miniconda3/envs/r_env/lib/R/library"

# %%
installed.packages()[,c("Package", "Version", "LibPath")]
# Out:
#              Package      Version
# DBI          DBI          1.2.3
# IRdisplay    IRdisplay    1.1
# IRkernel     IRkernel     1.3.2
# KernSmooth   KernSmooth   2.23-26
# MASS         MASS         7.3-64
# Matrix       Matrix       1.7-3
# ModelMetrics ModelMetrics 1.2.2.2
# R6           R6           2.6.1
# RColorBrewer RColorBrewer 1.1-3
# Rcpp         Rcpp         1.0.14
# RcppEigen    RcppEigen    0.3.4.0.2
# SQUAREM      SQUAREM      2021.1
# TTR          TTR          0.24.4
# askpass      askpass      1.2.1
# assertthat   assertthat   0.2.1
# backports    backports    1.5.0
# base         base         4.4.2
# base64enc    base64enc    0.1-3
# bit          bit          4.6.0
# bit64        bit64        4.6.0-1
# blob         blob         1.2.4
# boot         boot         1.3-31
# broom        broom        1.0.8
# bslib        bslib        0.9.0
# cachem       cachem       1.1.0
# callr        callr        3.7.6
# caret        caret        6.0-94
# cellranger   cellranger   1.1.0
# class        class        7.3-23
# cli          cli          3.6.4
# ⋮            ⋮            ⋮
# stringr      stringr      1.5.1
# survival     survival     3.8-3
# sys          sys          3.4.3
# systemfonts  systemfonts  1.2.1
# tcltk        tcltk        4.4.2
# textshaping  textshaping  0.4.0
# tibble       tibble       3.2.1
# tidyr        tidyr        1.3.1
# tidyselect   tidyselect   1.2.1
# tidyverse    tidyverse    2.0.0
# timeDate     timeDate     4041.110
# timechange   timechange   0.3.0
# tinytex      tinytex      0.56
# tools        tools        4.4.2
# triebeard    triebeard    0.4.1
# tzdb         tzdb         0.5.0
# urltools     urltools     1.7.3
# utf8         utf8         1.2.4
# utils        utils        4.4.2
# uuid         uuid         1.2-1
# vctrs        vctrs        0.6.5
# viridisLite  viridisLite  0.4.2
# vroom        vroom        1.6.5
# withr        withr        3.0.2
# xfun         xfun         0.52
# xml2         xml2         1.3.8
# xtable       xtable       1.8-4
# xts          xts          0.14.1
# yaml         yaml         2.3.10
# zoo          zoo          1.8-13
#              LibPath
# DBI          /Users/jun/miniconda3/envs/r_env/lib/R/library
# IRdisplay    /Users/jun/miniconda3/envs/r_env/lib/R/library
# IRkernel     /Users/jun/miniconda3/envs/r_env/lib/R/library
# KernSmooth   /Users/jun/miniconda3/envs/r_env/lib/R/library
# MASS         /Users/jun/miniconda3/envs/r_env/lib/R/library
# Matrix       /Users/jun/miniconda3/envs/r_env/lib/R/library
# ModelMetrics /Users/jun/miniconda3/envs/r_env/lib/R/library
# R6           /Users/jun/miniconda3/envs/r_env/lib/R/library
# RColorBrewer /Users/jun/miniconda3/envs/r_env/lib/R/library
# Rcpp         /Users/jun/miniconda3/envs/r_env/lib/R/library
# RcppEigen    /Users/jun/miniconda3/envs/r_env/lib/R/library
# SQUAREM      /Users/jun/miniconda3/envs/r_env/lib/R/library
# TTR          /Users/jun/miniconda3/envs/r_env/lib/R/library
# askpass      /Users/jun/miniconda3/envs/r_env/lib/R/library
# assertthat   /Users/jun/miniconda3/envs/r_env/lib/R/library
# backports    /Users/jun/miniconda3/envs/r_env/lib/R/library
# base         /Users/jun/miniconda3/envs/r_env/lib/R/library
# base64enc    /Users/jun/miniconda3/envs/r_env/lib/R/library
# bit          /Users/jun/miniconda3/envs/r_env/lib/R/library
# bit64        /Users/jun/miniconda3/envs/r_env/lib/R/library
# blob         /Users/jun/miniconda3/envs/r_env/lib/R/library
# boot         /Users/jun/miniconda3/envs/r_env/lib/R/library
# broom        /Users/jun/miniconda3/envs/r_env/lib/R/library
# bslib        /Users/jun/miniconda3/envs/r_env/lib/R/library
# cachem       /Users/jun/miniconda3/envs/r_env/lib/R/library
# callr        /Users/jun/miniconda3/envs/r_env/lib/R/library
# caret        /Users/jun/miniconda3/envs/r_env/lib/R/library
# cellranger   /Users/jun/miniconda3/envs/r_env/lib/R/library
# class        /Users/jun/miniconda3/envs/r_env/lib/R/library
# cli          /Users/jun/miniconda3/envs/r_env/lib/R/library
# ⋮            ⋮
# stringr      /Users/jun/miniconda3/envs/r_env/lib/R/library
# survival     /Users/jun/miniconda3/envs/r_env/lib/R/library
# sys          /Users/jun/miniconda3/envs/r_env/lib/R/library
# systemfonts  /Users/jun/miniconda3/envs/r_env/lib/R/library
# tcltk        /Users/jun/miniconda3/envs/r_env/lib/R/library
# textshaping  /Users/jun/miniconda3/envs/r_env/lib/R/library
# tibble       /Users/jun/miniconda3/envs/r_env/lib/R/library
# tidyr        /Users/jun/miniconda3/envs/r_env/lib/R/library
# tidyselect   /Users/jun/miniconda3/envs/r_env/lib/R/library
# tidyverse    /Users/jun/miniconda3/envs/r_env/lib/R/library
# timeDate     /Users/jun/miniconda3/envs/r_env/lib/R/library
# timechange   /Users/jun/miniconda3/envs/r_env/lib/R/library
# tinytex      /Users/jun/miniconda3/envs/r_env/lib/R/library
# tools        /Users/jun/miniconda3/envs/r_env/lib/R/library
# triebeard    /Users/jun/miniconda3/envs/r_env/lib/R/library
# tzdb         /Users/jun/miniconda3/envs/r_env/lib/R/library
# urltools     /Users/jun/miniconda3/envs/r_env/lib/R/library
# utf8         /Users/jun/miniconda3/envs/r_env/lib/R/library
# utils        /Users/jun/miniconda3/envs/r_env/lib/R/library
# uuid         /Users/jun/miniconda3/envs/r_env/lib/R/library
# vctrs        /Users/jun/miniconda3/envs/r_env/lib/R/library
# viridisLite  /Users/jun/miniconda3/envs/r_env/lib/R/library
# vroom        /Users/jun/miniconda3/envs/r_env/lib/R/library
# withr        /Users/jun/miniconda3/envs/r_env/lib/R/library
# xfun         /Users/jun/miniconda3/envs/r_env/lib/R/library
# xml2         /Users/jun/miniconda3/envs/r_env/lib/R/library
# xtable       /Users/jun/miniconda3/envs/r_env/lib/R/library
# xts          /Users/jun/miniconda3/envs/r_env/lib/R/library
# yaml         /Users/jun/miniconda3/envs/r_env/lib/R/library
# zoo          /Users/jun/miniconda3/envs/r_env/lib/R/library

# %%
library(ggplot2)
library(class)  # for knn
library("glmnet")
library("BiocManager")
library("ExperimentHub")
# Out:
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, saveRDS, setdiff, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: AnnotationHub
#
# Loading required package: BiocFileCache
#
# Loading required package: dbplyr
